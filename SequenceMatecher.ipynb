# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !pip install contractions
# !pip install indic-nlp-library
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 5.4 MB/s eta 0:00:00
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.1 MB/s eta 0:00:00
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.4.0-py3-none-any.whl (12 kB)
# Collecting sphinx-rtd-theme (from indic-nlp-library)
#   Downloading sphinx_rtd_theme-2.0.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 28.4 MB/s eta 0:00:00
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->indic-nlp-library) (2024.1)
# Requirement already satisfied: sphinx>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library) (5.0.2)
# Requirement already satisfied: docutils<0.21 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->indic-nlp-library) (0.18.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->indic-nlp-library)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.0.7)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.1.3)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.14.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (0.7.16)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.5.0->sphinx>=1.2.0->sphinx-argparse->indic-nlp-library) (2024.2.2)
# Installing collected packages: morfessor, sphinxcontrib-jquery, sphinx-argparse, sphinx-rtd-theme, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.4.0 sphinx-rtd-theme-2.0.0 sphinxcontrib-jquery-4.1

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Copy of Copy of shareddocgog.csv')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Pre-processing**

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string
import contractions

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Define punctuation set
punctuation_set = set(string.punctuation)

# Function for expanding contractions
def expand_contractions(text):
    return contractions.fix(text)

# Function for tokenization
def tokenize(text):
    return word_tokenize(text)

# Function for removing punctuation
def remove_punctuation(tokens):
    return [word for word in tokens if word not in punctuation_set]

# Iterate over each row in the dataset
for index, row in df.iterrows():
    hindi_idiom = row['hindi_idiom']
    english_idiom = row['english_idiom']

    # Expand contractions
    english_idiom = expand_contractions(english_idiom)

    # Tokenization
    hindi_tokens = tokenize(hindi_idiom)
    english_tokens = tokenize(english_idiom)

    # Punctuation removal
    hindi_tokens_no_punc = remove_punctuation(hindi_tokens)
    english_tokens_no_punc = remove_punctuation(english_tokens)

    print("Hindi idiom:", hindi_idiom)
    print("English idiom:", english_idiom)
    print("\nTokenization:")
    print("Hindi tokens:", hindi_tokens)
    print("English tokens:", english_tokens)
    print("\nLowercasing:")
    print("\nPunctuation Removal:")
    print("Hindi tokens without punctuation:", hindi_tokens_no_punc)
    print("English tokens without punctuation:", english_tokens_no_punc)
    print("\n--------------------------------------------\n")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Streaming output truncated to the last 5000 lines.
# Hindi tokens without punctuation: ['चोर', '–', 'चोर', 'मौसेरे', 'भाई']
# English tokens without punctuation: ['Birds', 'of', 'same', 'feather', 'flock', 'together']
#
# --------------------------------------------
#
# Hindi idiom: आप भले तो जग भला
# English idiom: Good mind, good find
#
# Tokenization:
# Hindi tokens: ['आप', 'भले', 'तो', 'जग', 'भला']
# English tokens: ['Good', 'mind', ',', 'good', 'find']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आप', 'भले', 'तो', 'जग', 'भला']
# English tokens without punctuation: ['Good', 'mind', 'good', 'find']
#
# --------------------------------------------
#
# Hindi idiom: एक हाथ से ताली नहीं बजती
# English idiom: It takes two to make a quarrel
#
# Tokenization:
# Hindi tokens: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens: ['It', 'takes', 'two', 'to', 'make', 'a', 'quarrel']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens without punctuation: ['It', 'takes', 'two', 'to', 'make', 'a', 'quarrel']
#
# --------------------------------------------
#
# Hindi idiom: जो गरजते हैं वो बरसते नहीं
# English idiom: Barking dogs seldom bite
#
# Tokenization:
# Hindi tokens: ['जो', 'गरजते', 'हैं', 'वो', 'बरसते', 'नहीं']
# English tokens: ['Barking', 'dogs', 'seldom', 'bite']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जो', 'गरजते', 'हैं', 'वो', 'बरसते', 'नहीं']
# English tokens without punctuation: ['Barking', 'dogs', 'seldom', 'bite']
#
# --------------------------------------------
#
# Hindi idiom: लालच बुरी बला है
# English idiom: Avarice is root of all evils
#
# Tokenization:
# Hindi tokens: ['लालच', 'बुरी', 'बला', 'है']
# English tokens: ['Avarice', 'is', 'root', 'of', 'all', 'evils']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['लालच', 'बुरी', 'बला', 'है']
# English tokens without punctuation: ['Avarice', 'is', 'root', 'of', 'all', 'evils']
#
# --------------------------------------------
#
# Hindi idiom: चार दिन की चांदनी फिर अँधेरी रात
# English idiom: A nine days wonder
#
# Tokenization:
# Hindi tokens: ['चार', 'दिन', 'की', 'चांदनी', 'फिर', 'अँधेरी', 'रात']
# English tokens: ['A', 'nine', 'days', 'wonder']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चार', 'दिन', 'की', 'चांदनी', 'फिर', 'अँधेरी', 'रात']
# English tokens without punctuation: ['A', 'nine', 'days', 'wonder']
#
# --------------------------------------------
#
# Hindi idiom: बोए पेड़ बबूल का तो आम कहाँ से होय
# English idiom: Gather thistles & expect pickles
#
# Tokenization:
# Hindi tokens: ['बोए', 'पेड़', 'बबूल', 'का', 'तो', 'आम', 'कहाँ', 'से', 'होय']
# English tokens: ['Gather', 'thistles', '&', 'expect', 'pickles']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बोए', 'पेड़', 'बबूल', 'का', 'तो', 'आम', 'कहाँ', 'से', 'होय']
# English tokens without punctuation: ['Gather', 'thistles', 'expect', 'pickles']
#
# --------------------------------------------
#
# Hindi idiom: ऊँट के मुंह में जीरा
# English idiom: A drop in the Ocean
#
# Tokenization:
# Hindi tokens: ['ऊँट', 'के', 'मुंह', 'में', 'जीरा']
# English tokens: ['A', 'drop', 'in', 'the', 'Ocean']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['ऊँट', 'के', 'मुंह', 'में', 'जीरा']
# English tokens without punctuation: ['A', 'drop', 'in', 'the', 'Ocean']
#
# --------------------------------------------
#
# Hindi idiom: दूध का जल छाछ को भी फूंक – फूंक कर पीता है
# English idiom: A burnt child dreads the fire
#
# Tokenization:
# Hindi tokens: ['दूध', 'का', 'जल', 'छाछ', 'को', 'भी', 'फूंक', '–', 'फूंक', 'कर', 'पीता', 'है']
# English tokens: ['A', 'burnt', 'child', 'dreads', 'the', 'fire']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['दूध', 'का', 'जल', 'छाछ', 'को', 'भी', 'फूंक', '–', 'फूंक', 'कर', 'पीता', 'है']
# English tokens without punctuation: ['A', 'burnt', 'child', 'dreads', 'the', 'fire']
#
# --------------------------------------------
#
# Hindi idiom: डूबते को तिनके का सहारा
# English idiom: Drowning man catches at straw
#
# Tokenization:
# Hindi tokens: ['डूबते', 'को', 'तिनके', 'का', 'सहारा']
# English tokens: ['Drowning', 'man', 'catches', 'at', 'straw']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['डूबते', 'को', 'तिनके', 'का', 'सहारा']
# English tokens without punctuation: ['Drowning', 'man', 'catches', 'at', 'straw']
#
# --------------------------------------------
#
# Hindi idiom: जैसा राजा वैसी प्रजा
# English idiom: As the king so are the subjects
#
# Tokenization:
# Hindi tokens: ['जैसा', 'राजा', 'वैसी', 'प्रजा']
# English tokens: ['As', 'the', 'king', 'so', 'are', 'the', 'subjects']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जैसा', 'राजा', 'वैसी', 'प्रजा']
# English tokens without punctuation: ['As', 'the', 'king', 'so', 'are', 'the', 'subjects']
#
# --------------------------------------------
#
# Hindi idiom: मुख में राम बगल में छूरी
# English idiom: A honey tongue , a heart of gall
#
# Tokenization:
# Hindi tokens: ['मुख', 'में', 'राम', 'बगल', 'में', 'छूरी']
# English tokens: ['A', 'honey', 'tongue', ',', 'a', 'heart', 'of', 'gall']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['मुख', 'में', 'राम', 'बगल', 'में', 'छूरी']
# English tokens without punctuation: ['A', 'honey', 'tongue', 'a', 'heart', 'of', 'gall']
#
# --------------------------------------------
#
# Hindi idiom: दूर के ढोल सुहावने लगते हैं
# English idiom: Grass on the other side always looks greener
#
# Tokenization:
# Hindi tokens: ['दूर', 'के', 'ढोल', 'सुहावने', 'लगते', 'हैं']
# English tokens: ['Grass', 'on', 'the', 'other', 'side', 'always', 'looks', 'greener']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['दूर', 'के', 'ढोल', 'सुहावने', 'लगते', 'हैं']
# English tokens without punctuation: ['Grass', 'on', 'the', 'other', 'side', 'always', 'looks', 'greener']
#
# --------------------------------------------
#
# Hindi idiom: हर चमकने वाली चीज सोना नहीं होती
# English idiom: All that glitters is not gold
#
# Tokenization:
# Hindi tokens: ['हर', 'चमकने', 'वाली', 'चीज', 'सोना', 'नहीं', 'होती']
# English tokens: ['All', 'that', 'glitters', 'is', 'not', 'gold']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['हर', 'चमकने', 'वाली', 'चीज', 'सोना', 'नहीं', 'होती']
# English tokens without punctuation: ['All', 'that', 'glitters', 'is', 'not', 'gold']
#
# --------------------------------------------
#
# Hindi idiom: अब पछताए होत क्या जब चिड़िया चुग गई खेत
# English idiom: No use crying over spilled milk
#
# Tokenization:
# Hindi tokens: ['अब', 'पछताए', 'होत', 'क्या', 'जब', 'चिड़िया', 'चुग', 'गई', 'खेत']
# English tokens: ['No', 'use', 'crying', 'over', 'spilled', 'milk']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अब', 'पछताए', 'होत', 'क्या', 'जब', 'चिड़िया', 'चुग', 'गई', 'खेत']
# English tokens without punctuation: ['No', 'use', 'crying', 'over', 'spilled', 'milk']
#
# --------------------------------------------
#
# Hindi idiom: जाति ना पूछो साधु की; पूछ लीजिए ज्ञान
# English idiom: Do not judge a book by its cover
#
# Tokenization:
# Hindi tokens: ['जाति', 'ना', 'पूछो', 'साधु', 'की', ';', 'पूछ', 'लीजिए', 'ज्ञान']
# English tokens: ['Do', 'not', 'judge', 'a', 'book', 'by', 'its', 'cover']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जाति', 'ना', 'पूछो', 'साधु', 'की', 'पूछ', 'लीजिए', 'ज्ञान']
# English tokens without punctuation: ['Do', 'not', 'judge', 'a', 'book', 'by', 'its', 'cover']
#
# --------------------------------------------
#
# Hindi idiom: अंत भला तो सब भला
# English idiom: All is well that ends well
#
# Tokenization:
# Hindi tokens: ['अंत', 'भला', 'तो', 'सब', 'भला']
# English tokens: ['All', 'is', 'well', 'that', 'ends', 'well']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अंत', 'भला', 'तो', 'सब', 'भला']
# English tokens without punctuation: ['All', 'is', 'well', 'that', 'ends', 'well']
#
# --------------------------------------------
#
# Hindi idiom: बात बदल सकती है
# English idiom: There is more than one way to skin a cat
#
# Tokenization:
# Hindi tokens: ['बात', 'बदल', 'सकती', 'है']
# English tokens: ['There', 'is', 'more', 'than', 'one', 'way', 'to', 'skin', 'a', 'cat']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बात', 'बदल', 'सकती', 'है']
# English tokens without punctuation: ['There', 'is', 'more', 'than', 'one', 'way', 'to', 'skin', 'a', 'cat']
#
# --------------------------------------------
#
# Hindi idiom: वो दिन कभी नहीं आएगा!
# English idiom: That will be the day!
#
# Tokenization:
# Hindi tokens: ['वो', 'दिन', 'कभी', 'नहीं', 'आएगा', '!']
# English tokens: ['That', 'will', 'be', 'the', 'day', '!']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['वो', 'दिन', 'कभी', 'नहीं', 'आएगा']
# English tokens without punctuation: ['That', 'will', 'be', 'the', 'day']
#
# --------------------------------------------
#
# Hindi idiom: यह अंतिम चाल है!
# English idiom: That is the last straw!
#
# Tokenization:
# Hindi tokens: ['यह', 'अंतिम', 'चाल', 'है', '!']
# English tokens: ['That', 'is', 'the', 'last', 'straw', '!']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['यह', 'अंतिम', 'चाल', 'है']
# English tokens without punctuation: ['That', 'is', 'the', 'last', 'straw']
#
# --------------------------------------------
#
# Hindi idiom: ऐसा ही होता है
# English idiom: That is the way the cookie crumbles
#
# Tokenization:
# Hindi tokens: ['ऐसा', 'ही', 'होता', 'है']
# English tokens: ['That', 'is', 'the', 'way', 'the', 'cookie', 'crumbles']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['ऐसा', 'ही', 'होता', 'है']
# English tokens without punctuation: ['That', 'is', 'the', 'way', 'the', 'cookie', 'crumbles']
#
# --------------------------------------------
#
# Hindi idiom: परख पूरा प्रमाण है
# English idiom: The proof of the pudding is in the eating
#
# Tokenization:
# Hindi tokens: ['परख', 'पूरा', 'प्रमाण', 'है']
# English tokens: ['The', 'proof', 'of', 'the', 'pudding', 'is', 'in', 'the', 'eating']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['परख', 'पूरा', 'प्रमाण', 'है']
# English tokens without punctuation: ['The', 'proof', 'of', 'the', 'pudding', 'is', 'in', 'the', 'eating']
#
# --------------------------------------------
#
# Hindi idiom: अभी सबसे अच्छा है
# English idiom: There is no time like the present
#
# Tokenization:
# Hindi tokens: ['अभी', 'सबसे', 'अच्छा', 'है']
# English tokens: ['There', 'is', 'no', 'time', 'like', 'the', 'present']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अभी', 'सबसे', 'अच्छा', 'है']
# English tokens without punctuation: ['There', 'is', 'no', 'time', 'like', 'the', 'present']
#
# --------------------------------------------
#
# Hindi idiom: कल दूसरा दिन है
# English idiom: Tomorrow is another day
#
# Tokenization:
# Hindi tokens: ['कल', 'दूसरा', 'दिन', 'है']
# English tokens: ['Tomorrow', 'is', 'another', 'day']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['कल', 'दूसरा', 'दिन', 'है']
# English tokens without punctuation: ['Tomorrow', 'is', 'another', 'day']
#
# --------------------------------------------
#
# Hindi idiom: उल्टा चोर कोतवाल को डांटे
# English idiom: The pot calling the kettle black
#
# Tokenization:
# Hindi tokens: ['उल्टा', 'चोर', 'कोतवाल', 'को', 'डांटे']
# English tokens: ['The', 'pot', 'calling', 'the', 'kettle', 'black']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['उल्टा', 'चोर', 'कोतवाल', 'को', 'डांटे']
# English tokens without punctuation: ['The', 'pot', 'calling', 'the', 'kettle', 'black']
#
# --------------------------------------------
#
# Hindi idiom: जैसा देश वैसा भेष
# English idiom: When in Rome, do as the Romans do
#
# Tokenization:
# Hindi tokens: ['जैसा', 'देश', 'वैसा', 'भेष']
# English tokens: ['When', 'in', 'Rome', ',', 'do', 'as', 'the', 'Romans', 'do']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जैसा', 'देश', 'वैसा', 'भेष']
# English tokens without punctuation: ['When', 'in', 'Rome', 'do', 'as', 'the', 'Romans', 'do']
#
# --------------------------------------------
#
# Hindi idiom: अंधों में काना राजा
# English idiom: In the land of the blind, the one-eyed man is king
#
# Tokenization:
# Hindi tokens: ['अंधों', 'में', 'काना', 'राजा']
# English tokens: ['In', 'the', 'land', 'of', 'the', 'blind', ',', 'the', 'one-eyed', 'man', 'is', 'king']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अंधों', 'में', 'काना', 'राजा']
# English tokens without punctuation: ['In', 'the', 'land', 'of', 'the', 'blind', 'the', 'one-eyed', 'man', 'is', 'king']
#
# --------------------------------------------
#
# Hindi idiom: भीगी बिली बनना
# English idiom: Play dumb
#
# Tokenization:
# Hindi tokens: ['भीगी', 'बिली', 'बनना']
# English tokens: ['Play', 'dumb']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['भीगी', 'बिली', 'बनना']
# English tokens without punctuation: ['Play', 'dumb']
#
# --------------------------------------------
#
# Hindi idiom: जिसकी लाठी उसकी भैंस
# English idiom: Might is right
#
# Tokenization:
# Hindi tokens: ['जिसकी', 'लाठी', 'उसकी', 'भैंस']
# English tokens: ['Might', 'is', 'right']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जिसकी', 'लाठी', 'उसकी', 'भैंस']
# English tokens without punctuation: ['Might', 'is', 'right']
#
# --------------------------------------------
#
# Hindi idiom: आप भले तो जग भला
# English idiom: If you are good, the world is good
#
# Tokenization:
# Hindi tokens: ['आप', 'भले', 'तो', 'जग', 'भला']
# English tokens: ['If', 'you', 'are', 'good', ',', 'the', 'world', 'is', 'good']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आप', 'भले', 'तो', 'जग', 'भला']
# English tokens without punctuation: ['If', 'you', 'are', 'good', 'the', 'world', 'is', 'good']
#
# --------------------------------------------
#
# Hindi idiom: घर की मुर्गी दाल बराबर
# English idiom: Familiarity breeds contempt
#
# Tokenization:
# Hindi tokens: ['घर', 'की', 'मुर्गी', 'दाल', 'बराबर']
# English tokens: ['Familiarity', 'breeds', 'contempt']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['घर', 'की', 'मुर्गी', 'दाल', 'बराबर']
# English tokens without punctuation: ['Familiarity', 'breeds', 'contempt']
#
# --------------------------------------------
#
# Hindi idiom: चोर की दाढ़ी में तिनका
# English idiom: A guilty conscience needs no accuser
#
# Tokenization:
# Hindi tokens: ['चोर', 'की', 'दाढ़ी', 'में', 'तिनका']
# English tokens: ['A', 'guilty', 'conscience', 'needs', 'no', 'accuser']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चोर', 'की', 'दाढ़ी', 'में', 'तिनका']
# English tokens without punctuation: ['A', 'guilty', 'conscience', 'needs', 'no', 'accuser']
#
# --------------------------------------------
#
# Hindi idiom: बादल गरजते हैं, बरसते नहीं
# English idiom: All talk and no action
#
# Tokenization:
# Hindi tokens: ['बादल', 'गरजते', 'हैं', ',', 'बरसते', 'नहीं']
# English tokens: ['All', 'talk', 'and', 'no', 'action']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बादल', 'गरजते', 'हैं', 'बरसते', 'नहीं']
# English tokens without punctuation: ['All', 'talk', 'and', 'no', 'action']
#
# --------------------------------------------
#
# Hindi idiom: जहां चाह, वहां राह
# English idiom: Where there is a will, there is a way
#
# Tokenization:
# Hindi tokens: ['जहां', 'चाह', ',', 'वहां', 'राह']
# English tokens: ['Where', 'there', 'is', 'a', 'will', ',', 'there', 'is', 'a', 'way']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जहां', 'चाह', 'वहां', 'राह']
# English tokens without punctuation: ['Where', 'there', 'is', 'a', 'will', 'there', 'is', 'a', 'way']
#
# --------------------------------------------
#
# Hindi idiom: धोबी का कुत्ता, न घर का न घाट का
# English idiom: A rolling stone gathers no moss
#
# Tokenization:
# Hindi tokens: ['धोबी', 'का', 'कुत्ता', ',', 'न', 'घर', 'का', 'न', 'घाट', 'का']
# English tokens: ['A', 'rolling', 'stone', 'gathers', 'no', 'moss']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['धोबी', 'का', 'कुत्ता', 'न', 'घर', 'का', 'न', 'घाट', 'का']
# English tokens without punctuation: ['A', 'rolling', 'stone', 'gathers', 'no', 'moss']
#
# --------------------------------------------
#
# Hindi idiom: चलती का नाम गाड़ी
# English idiom: Time and tide wait for none
#
# Tokenization:
# Hindi tokens: ['चलती', 'का', 'नाम', 'गाड़ी']
# English tokens: ['Time', 'and', 'tide', 'wait', 'for', 'none']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चलती', 'का', 'नाम', 'गाड़ी']
# English tokens without punctuation: ['Time', 'and', 'tide', 'wait', 'for', 'none']
#
# --------------------------------------------
#
# Hindi idiom: घर का भेदी, लंका ढाये
# English idiom: Beware of the Greeks bearing gifts
#
# Tokenization:
# Hindi tokens: ['घर', 'का', 'भेदी', ',', 'लंका', 'ढाये']
# English tokens: ['Beware', 'of', 'the', 'Greeks', 'bearing', 'gifts']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['घर', 'का', 'भेदी', 'लंका', 'ढाये']
# English tokens without punctuation: ['Beware', 'of', 'the', 'Greeks', 'bearing', 'gifts']
#
# --------------------------------------------
#
# Hindi idiom: खून पसीना बहाना
# English idiom: To work hard and sweat for something
#
# Tokenization:
# Hindi tokens: ['खून', 'पसीना', 'बहाना']
# English tokens: ['To', 'work', 'hard', 'and', 'sweat', 'for', 'something']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['खून', 'पसीना', 'बहाना']
# English tokens without punctuation: ['To', 'work', 'hard', 'and', 'sweat', 'for', 'something']
#
# --------------------------------------------
#
# Hindi idiom: नाच न जाने आंगन टेढ़ा
# English idiom: A bad workman blames his tools
#
# Tokenization:
# Hindi tokens: ['नाच', 'न', 'जाने', 'आंगन', 'टेढ़ा']
# English tokens: ['A', 'bad', 'workman', 'blames', 'his', 'tools']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['नाच', 'न', 'जाने', 'आंगन', 'टेढ़ा']
# English tokens without punctuation: ['A', 'bad', 'workman', 'blames', 'his', 'tools']
#
# --------------------------------------------
#
# Hindi idiom: एक पंथ दो काज
# English idiom: To kill two birds with one stone
#
# Tokenization:
# Hindi tokens: ['एक', 'पंथ', 'दो', 'काज']
# English tokens: ['To', 'kill', 'two', 'birds', 'with', 'one', 'stone']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'पंथ', 'दो', 'काज']
# English tokens without punctuation: ['To', 'kill', 'two', 'birds', 'with', 'one', 'stone']
#
# --------------------------------------------
#
# Hindi idiom: ऊंची दुकान फीका पकवान
# English idiom: Great boast, little roast
#
# Tokenization:
# Hindi tokens: ['ऊंची', 'दुकान', 'फीका', 'पकवान']
# English tokens: ['Great', 'boast', ',', 'little', 'roast']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['ऊंची', 'दुकान', 'फीका', 'पकवान']
# English tokens without punctuation: ['Great', 'boast', 'little', 'roast']
#
# --------------------------------------------
#
# Hindi idiom: आधी छोड़ पूरी को धावे, आधी मिले न पूरी पावे
# English idiom: He who grasps all things will lose all
#
# Tokenization:
# Hindi tokens: ['आधी', 'छोड़', 'पूरी', 'को', 'धावे', ',', 'आधी', 'मिले', 'न', 'पूरी', 'पावे']
# English tokens: ['He', 'who', 'grasps', 'all', 'things', 'will', 'lose', 'all']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आधी', 'छोड़', 'पूरी', 'को', 'धावे', 'आधी', 'मिले', 'न', 'पूरी', 'पावे']
# English tokens without punctuation: ['He', 'who', 'grasps', 'all', 'things', 'will', 'lose', 'all']
#
# --------------------------------------------
#
# Hindi idiom: एक मछली सारे तालाब को गंदा कर देती है
# English idiom: A black sheep infects the whole flock
#
# Tokenization:
# Hindi tokens: ['एक', 'मछली', 'सारे', 'तालाब', 'को', 'गंदा', 'कर', 'देती', 'है']
# English tokens: ['A', 'black', 'sheep', 'infects', 'the', 'whole', 'flock']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'मछली', 'सारे', 'तालाब', 'को', 'गंदा', 'कर', 'देती', 'है']
# English tokens without punctuation: ['A', 'black', 'sheep', 'infects', 'the', 'whole', 'flock']
#
# --------------------------------------------
#
# Hindi idiom: एक ही थाली के चट्टे बट्टे
# English idiom: Cast in the same mould
#
# Tokenization:
# Hindi tokens: ['एक', 'ही', 'थाली', 'के', 'चट्टे', 'बट्टे']
# English tokens: ['Cast', 'in', 'the', 'same', 'mould']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'ही', 'थाली', 'के', 'चट्टे', 'बट्टे']
# English tokens without punctuation: ['Cast', 'in', 'the', 'same', 'mould']
#
# --------------------------------------------
#
# Hindi idiom: एक हाथ से ताली नहीं बजती
# English idiom: It takes two to make a quarrel
#
# Tokenization:
# Hindi tokens: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens: ['It', 'takes', 'two', 'to', 'make', 'a', 'quarrel']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens without punctuation: ['It', 'takes', 'two', 'to', 'make', 'a', 'quarrel']
#
# --------------------------------------------
#
# Hindi idiom: बंदर क्या जाने अदरक का स्वाद
# English idiom: Casting pearls before swine
#
# Tokenization:
# Hindi tokens: ['बंदर', 'क्या', 'जाने', 'अदरक', 'का', 'स्वाद']
# English tokens: ['Casting', 'pearls', 'before', 'swine']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बंदर', 'क्या', 'जाने', 'अदरक', 'का', 'स्वाद']
# English tokens without punctuation: ['Casting', 'pearls', 'before', 'swine']
#
# --------------------------------------------
#
# Hindi idiom: दाल में काला
# English idiom: More to it than meets the eye
#
# Tokenization:
# Hindi tokens: ['दाल', 'में', 'काला']
# English tokens: ['More', 'to', 'it', 'than', 'meets', 'the', 'eye']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['दाल', 'में', 'काला']
# English tokens without punctuation: ['More', 'to', 'it', 'than', 'meets', 'the', 'eye']
#
# --------------------------------------------
#
# Hindi idiom: दूर के ढोल सुहावने लगते हैं
# English idiom: The grass seems greener on the other side
#
# Tokenization:
# Hindi tokens: ['दूर', 'के', 'ढोल', 'सुहावने', 'लगते', 'हैं']
# English tokens: ['The', 'grass', 'seems', 'greener', 'on', 'the', 'other', 'side']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['दूर', 'के', 'ढोल', 'सुहावने', 'लगते', 'हैं']
# English tokens without punctuation: ['The', 'grass', 'seems', 'greener', 'on', 'the', 'other', 'side']
#
# --------------------------------------------
#
# Hindi idiom: आगे कुआँ पीछे खाई
# English idiom: Between the devil and the deep sea
#
# Tokenization:
# Hindi tokens: ['आगे', 'कुआँ', 'पीछे', 'खाई']
# English tokens: ['Between', 'the', 'devil', 'and', 'the', 'deep', 'sea']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आगे', 'कुआँ', 'पीछे', 'खाई']
# English tokens without punctuation: ['Between', 'the', 'devil', 'and', 'the', 'deep', 'sea']
#
# --------------------------------------------
#
# Hindi idiom: जितनी लंबी चादर हो उतनी ही जोड़ी फेलाना चाहिए
# English idiom: Cut your dress according to your cloth
#
# Tokenization:
# Hindi tokens: ['जितनी', 'लंबी', 'चादर', 'हो', 'उतनी', 'ही', 'जोड़ी', 'फेलाना', 'चाहिए']
# English tokens: ['Cut', 'your', 'dress', 'according', 'to', 'your', 'cloth']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जितनी', 'लंबी', 'चादर', 'हो', 'उतनी', 'ही', 'जोड़ी', 'फेलाना', 'चाहिए']
# English tokens without punctuation: ['Cut', 'your', 'dress', 'according', 'to', 'your', 'cloth']
#
# --------------------------------------------
#
# Hindi idiom: दूध का जला चास भी फूँक-फूँक कर पीता है
# English idiom: Once bitten twice shy
#
# Tokenization:
# Hindi tokens: ['दूध', 'का', 'जला', 'चास', 'भी', 'फूँक-फूँक', 'कर', 'पीता', 'है']
# English tokens: ['Once', 'bitten', 'twice', 'shy']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['दूध', 'का', 'जला', 'चास', 'भी', 'फूँक-फूँक', 'कर', 'पीता', 'है']
# English tokens without punctuation: ['Once', 'bitten', 'twice', 'shy']
#
# --------------------------------------------
#
# Hindi idiom: एक म्यान में दो तलवारें नहीं समाति
# English idiom: No man can serve two masters
#
# Tokenization:
# Hindi tokens: ['एक', 'म्यान', 'में', 'दो', 'तलवारें', 'नहीं', 'समाति']
# English tokens: ['No', 'man', 'can', 'serve', 'two', 'masters']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'म्यान', 'में', 'दो', 'तलवारें', 'नहीं', 'समाति']
# English tokens without punctuation: ['No', 'man', 'can', 'serve', 'two', 'masters']
#
# --------------------------------------------
#
# Hindi idiom: खोट्टा चना बाजे घना
# English idiom: Empty vessels make more noise
#
# Tokenization:
# Hindi tokens: ['खोट्टा', 'चना', 'बाजे', 'घना']
# English tokens: ['Empty', 'vessels', 'make', 'more', 'noise']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['खोट्टा', 'चना', 'बाजे', 'घना']
# English tokens without punctuation: ['Empty', 'vessels', 'make', 'more', 'noise']
#
# --------------------------------------------
#
# Hindi idiom: आप सुखी तो जग सुखी
# English idiom: He that is warm thinks all are so
#
# Tokenization:
# Hindi tokens: ['आप', 'सुखी', 'तो', 'जग', 'सुखी']
# English tokens: ['He', 'that', 'is', 'warm', 'thinks', 'all', 'are', 'so']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आप', 'सुखी', 'तो', 'जग', 'सुखी']
# English tokens without punctuation: ['He', 'that', 'is', 'warm', 'thinks', 'all', 'are', 'so']
#
# --------------------------------------------
#
# Hindi idiom: आम से टपका बगल में अटका
# English idiom: Out of the frying pan into the fire
#
# Tokenization:
# Hindi tokens: ['आम', 'से', 'टपका', 'बगल', 'में', 'अटका']
# English tokens: ['Out', 'of', 'the', 'frying', 'pan', 'into', 'the', 'fire']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आम', 'से', 'टपका', 'बगल', 'में', 'अटका']
# English tokens without punctuation: ['Out', 'of', 'the', 'frying', 'pan', 'into', 'the', 'fire']
#
# --------------------------------------------
#
# Hindi idiom: अपने मुहं मियां मिट्ठू मत बनो
# English idiom: Self praise is no recommendation
#
# Tokenization:
# Hindi tokens: ['अपने', 'मुहं', 'मियां', 'मिट्ठू', 'मत', 'बनो']
# English tokens: ['Self', 'praise', 'is', 'no', 'recommendation']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अपने', 'मुहं', 'मियां', 'मिट्ठू', 'मत', 'बनो']
# English tokens without punctuation: ['Self', 'praise', 'is', 'no', 'recommendation']
#
# --------------------------------------------
#
# Hindi idiom: आगे दौड़ पीछे चौड
# English idiom: Haste makes waste
#
# Tokenization:
# Hindi tokens: ['आगे', 'दौड़', 'पीछे', 'चौड']
# English tokens: ['Haste', 'makes', 'waste']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आगे', 'दौड़', 'पीछे', 'चौड']
# English tokens without punctuation: ['Haste', 'makes', 'waste']
#
# --------------------------------------------
#
# Hindi idiom: आँख ओझल पहाड़ ओझल
# English idiom: Out of sight, out of mind
#
# Tokenization:
# Hindi tokens: ['आँख', 'ओझल', 'पहाड़', 'ओझल']
# English tokens: ['Out', 'of', 'sight', ',', 'out', 'of', 'mind']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आँख', 'ओझल', 'पहाड़', 'ओझल']
# English tokens without punctuation: ['Out', 'of', 'sight', 'out', 'of', 'mind']
#
# --------------------------------------------
#
# Hindi idiom: आगे दौड़ पीछे चौड
# English idiom: Hurry spoils curry
#
# Tokenization:
# Hindi tokens: ['आगे', 'दौड़', 'पीछे', 'चौड']
# English tokens: ['Hurry', 'spoils', 'curry']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आगे', 'दौड़', 'पीछे', 'चौड']
# English tokens without punctuation: ['Hurry', 'spoils', 'curry']
#
# --------------------------------------------
#
# Hindi idiom: आवश्यकता अविष्कार की जननी है
# English idiom: Necessity is the mother of invention
#
# Tokenization:
# Hindi tokens: ['आवश्यकता', 'अविष्कार', 'की', 'जननी', 'है']
# English tokens: ['Necessity', 'is', 'the', 'mother', 'of', 'invention']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आवश्यकता', 'अविष्कार', 'की', 'जननी', 'है']
# English tokens without punctuation: ['Necessity', 'is', 'the', 'mother', 'of', 'invention']
#
# --------------------------------------------
#
# Hindi idiom: अन्धा क्या जाने बसंत की बहार
# English idiom: A blindman is no judge of colours
#
# Tokenization:
# Hindi tokens: ['अन्धा', 'क्या', 'जाने', 'बसंत', 'की', 'बहार']
# English tokens: ['A', 'blindman', 'is', 'no', 'judge', 'of', 'colours']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अन्धा', 'क्या', 'जाने', 'बसंत', 'की', 'बहार']
# English tokens without punctuation: ['A', 'blindman', 'is', 'no', 'judge', 'of', 'colours']
#
# --------------------------------------------
#
# Hindi idiom: अपना अपना, पराया पराया
# English idiom: Blood is thicker than water
#
# Tokenization:
# Hindi tokens: ['अपना', 'अपना', ',', 'पराया', 'पराया']
# English tokens: ['Blood', 'is', 'thicker', 'than', 'water']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अपना', 'अपना', 'पराया', 'पराया']
# English tokens without punctuation: ['Blood', 'is', 'thicker', 'than', 'water']
#
# --------------------------------------------
#
# Hindi idiom: अच्छा वही जो अच्छा कार्य करे
# English idiom: Handsome is that handsome does
#
# Tokenization:
# Hindi tokens: ['अच्छा', 'वही', 'जो', 'अच्छा', 'कार्य', 'करे']
# English tokens: ['Handsome', 'is', 'that', 'handsome', 'does']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अच्छा', 'वही', 'जो', 'अच्छा', 'कार्य', 'करे']
# English tokens without punctuation: ['Handsome', 'is', 'that', 'handsome', 'does']
#
# --------------------------------------------
#
# Hindi idiom: इलाज से परहेज अच्छा
# English idiom: Prevention is better than cure
#
# Tokenization:
# Hindi tokens: ['इलाज', 'से', 'परहेज', 'अच्छा']
# English tokens: ['Prevention', 'is', 'better', 'than', 'cure']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['इलाज', 'से', 'परहेज', 'अच्छा']
# English tokens without punctuation: ['Prevention', 'is', 'better', 'than', 'cure']
#
# --------------------------------------------
#
# Hindi idiom: उपदेश देने से स्वयं उपदेशों पर चलना बेहतर है
# English idiom: Example is better than precept
#
# Tokenization:
# Hindi tokens: ['उपदेश', 'देने', 'से', 'स्वयं', 'उपदेशों', 'पर', 'चलना', 'बेहतर', 'है']
# English tokens: ['Example', 'is', 'better', 'than', 'precept']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['उपदेश', 'देने', 'से', 'स्वयं', 'उपदेशों', 'पर', 'चलना', 'बेहतर', 'है']
# English tokens without punctuation: ['Example', 'is', 'better', 'than', 'precept']
#
# --------------------------------------------
#
# Hindi idiom: एक हाथ से ताली नहीं बजती
# English idiom: It takes two make a row
#
# Tokenization:
# Hindi tokens: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens: ['It', 'takes', 'two', 'make', 'a', 'row']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens without punctuation: ['It', 'takes', 'two', 'make', 'a', 'row']
#
# --------------------------------------------
#
# Hindi idiom: एक पंथ दो काज
# English idiom: Two kill two birds with one stone
#
# Tokenization:
# Hindi tokens: ['एक', 'पंथ', 'दो', 'काज']
# English tokens: ['Two', 'kill', 'two', 'birds', 'with', 'one', 'stone']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'पंथ', 'दो', 'काज']
# English tokens without punctuation: ['Two', 'kill', 'two', 'birds', 'with', 'one', 'stone']
#
# --------------------------------------------
#
# Hindi idiom: एकता में बल
# English idiom: Union is Strength
#
# Tokenization:
# Hindi tokens: ['एकता', 'में', 'बल']
# English tokens: ['Union', 'is', 'Strength']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एकता', 'में', 'बल']
# English tokens without punctuation: ['Union', 'is', 'Strength']
#
# --------------------------------------------
#
# Hindi idiom: एक चुप सौ सुख
# English idiom: Silence is the best
#
# Tokenization:
# Hindi tokens: ['एक', 'चुप', 'सौ', 'सुख']
# English tokens: ['Silence', 'is', 'the', 'best']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'चुप', 'सौ', 'सुख']
# English tokens without punctuation: ['Silence', 'is', 'the', 'best']
#
# --------------------------------------------
#
# Hindi idiom: एक हाथ से ताली नहीं बजती
# English idiom: It takes two to make a quarrel
#
# Tokenization:
# Hindi tokens: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens: ['It', 'takes', 'two', 'to', 'make', 'a', 'quarrel']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'हाथ', 'से', 'ताली', 'नहीं', 'बजती']
# English tokens without punctuation: ['It', 'takes', 'two', 'to', 'make', 'a', 'quarrel']
#
# --------------------------------------------
#
# Hindi idiom: एक गंदी मछली सारे तालाब को गंदा कर देती है
# English idiom: A single sheep infects the whole flock
#
# Tokenization:
# Hindi tokens: ['एक', 'गंदी', 'मछली', 'सारे', 'तालाब', 'को', 'गंदा', 'कर', 'देती', 'है']
# English tokens: ['A', 'single', 'sheep', 'infects', 'the', 'whole', 'flock']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['एक', 'गंदी', 'मछली', 'सारे', 'तालाब', 'को', 'गंदा', 'कर', 'देती', 'है']
# English tokens without punctuation: ['A', 'single', 'sheep', 'infects', 'the', 'whole', 'flock']
#
# --------------------------------------------
#
# Hindi idiom: ऊँची दुकान फीका पकवान
# English idiom: Much cry, little wool
#
# Tokenization:
# Hindi tokens: ['ऊँची', 'दुकान', 'फीका', 'पकवान']
# English tokens: ['Much', 'cry', ',', 'little', 'wool']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['ऊँची', 'दुकान', 'फीका', 'पकवान']
# English tokens without punctuation: ['Much', 'cry', 'little', 'wool']
#
# --------------------------------------------
#
# Hindi idiom: कर भला हो भला
# English idiom: Goodness never goes unrewarded
#
# Tokenization:
# Hindi tokens: ['कर', 'भला', 'हो', 'भला']
# English tokens: ['Goodness', 'never', 'goes', 'unrewarded']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['कर', 'भला', 'हो', 'भला']
# English tokens without punctuation: ['Goodness', 'never', 'goes', 'unrewarded']
#
# --------------------------------------------
#
# Hindi idiom: कोठी वाला रोये, छप्पर वाला सोये
# English idiom: Uneasy lies the head that wears the crown
#
# Tokenization:
# Hindi tokens: ['कोठी', 'वाला', 'रोये', ',', 'छप्पर', 'वाला', 'सोये']
# English tokens: ['Uneasy', 'lies', 'the', 'head', 'that', 'wears', 'the', 'crown']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['कोठी', 'वाला', 'रोये', 'छप्पर', 'वाला', 'सोये']
# English tokens without punctuation: ['Uneasy', 'lies', 'the', 'head', 'that', 'wears', 'the', 'crown']
#
# --------------------------------------------
#
# Hindi idiom: कुत्ते का कुत्ता बैरी
# English idiom: Two of a trade seldom agree
#
# Tokenization:
# Hindi tokens: ['कुत्ते', 'का', 'कुत्ता', 'बैरी']
# English tokens: ['Two', 'of', 'a', 'trade', 'seldom', 'agree']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['कुत्ते', 'का', 'कुत्ता', 'बैरी']
# English tokens without punctuation: ['Two', 'of', 'a', 'trade', 'seldom', 'agree']
#
# --------------------------------------------
#
# Hindi idiom: कद्र खोद देता है रोज का आना जाना
# English idiom: Familiarity breeds contempt
#
# Tokenization:
# Hindi tokens: ['कद्र', 'खोद', 'देता', 'है', 'रोज', 'का', 'आना', 'जाना']
# English tokens: ['Familiarity', 'breeds', 'contempt']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['कद्र', 'खोद', 'देता', 'है', 'रोज', 'का', 'आना', 'जाना']
# English tokens without punctuation: ['Familiarity', 'breeds', 'contempt']
#
# --------------------------------------------
#
# Hindi idiom: करत करत अभ्यास से जड्मुती होत सुजान
# English idiom: Practice makes a man perfect
#
# Tokenization:
# Hindi tokens: ['करत', 'करत', 'अभ्यास', 'से', 'जड्मुती', 'होत', 'सुजान']
# English tokens: ['Practice', 'makes', 'a', 'man', 'perfect']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['करत', 'करत', 'अभ्यास', 'से', 'जड्मुती', 'होत', 'सुजान']
# English tokens without punctuation: ['Practice', 'makes', 'a', 'man', 'perfect']
#
# --------------------------------------------
#
# Hindi idiom: खाली बैठे सैतानी सूझे
# English idiom: An idle man’s brain is a devil’s workshop
#
# Tokenization:
# Hindi tokens: ['खाली', 'बैठे', 'सैतानी', 'सूझे']
# English tokens: ['An', 'idle', 'man', '’', 's', 'brain', 'is', 'a', 'devil', '’', 's', 'workshop']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['खाली', 'बैठे', 'सैतानी', 'सूझे']
# English tokens without punctuation: ['An', 'idle', 'man', '’', 's', 'brain', 'is', 'a', 'devil', '’', 's', 'workshop']
#
# --------------------------------------------
#
# Hindi idiom: खोदा पहाड़ निकली चुहिया
# English idiom: Much ado about nothing
#
# Tokenization:
# Hindi tokens: ['खोदा', 'पहाड़', 'निकली', 'चुहिया']
# English tokens: ['Much', 'ado', 'about', 'nothing']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['खोदा', 'पहाड़', 'निकली', 'चुहिया']
# English tokens without punctuation: ['Much', 'ado', 'about', 'nothing']
#
# --------------------------------------------
#
# Hindi idiom: कानी के ब्याह में नौ सौ जोखिम
# English idiom: There is many a slip between the cup and the lip
#
# Tokenization:
# Hindi tokens: ['कानी', 'के', 'ब्याह', 'में', 'नौ', 'सौ', 'जोखिम']
# English tokens: ['There', 'is', 'many', 'a', 'slip', 'between', 'the', 'cup', 'and', 'the', 'lip']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['कानी', 'के', 'ब्याह', 'में', 'नौ', 'सौ', 'जोखिम']
# English tokens without punctuation: ['There', 'is', 'many', 'a', 'slip', 'between', 'the', 'cup', 'and', 'the', 'lip']
#
# --------------------------------------------
#
# Hindi idiom: गले पड़ा ढ़ोल बजाना ही पड़ता है
# English idiom: What cannot be cured must be endured
#
# Tokenization:
# Hindi tokens: ['गले', 'पड़ा', 'ढ़ोल', 'बजाना', 'ही', 'पड़ता', 'है']
# English tokens: ['What', 'can', 'not', 'be', 'cured', 'must', 'be', 'endured']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['गले', 'पड़ा', 'ढ़ोल', 'बजाना', 'ही', 'पड़ता', 'है']
# English tokens without punctuation: ['What', 'can', 'not', 'be', 'cured', 'must', 'be', 'endured']
#
# --------------------------------------------
#
# Hindi idiom: घर घोडा नकास मोल
# English idiom: To build castles in the air
#
# Tokenization:
# Hindi tokens: ['घर', 'घोडा', 'नकास', 'मोल']
# English tokens: ['To', 'build', 'castles', 'in', 'the', 'air']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['घर', 'घोडा', 'नकास', 'मोल']
# English tokens without punctuation: ['To', 'build', 'castles', 'in', 'the', 'air']
#
# --------------------------------------------
#
# Hindi idiom: घर वाला घर नहीं हमें किसी का डर नहीं
# English idiom: When the cat is away, the mice will play
#
# Tokenization:
# Hindi tokens: ['घर', 'वाला', 'घर', 'नहीं', 'हमें', 'किसी', 'का', 'डर', 'नहीं']
# English tokens: ['When', 'the', 'cat', 'is', 'away', ',', 'the', 'mice', 'will', 'play']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['घर', 'वाला', 'घर', 'नहीं', 'हमें', 'किसी', 'का', 'डर', 'नहीं']
# English tokens without punctuation: ['When', 'the', 'cat', 'is', 'away', 'the', 'mice', 'will', 'play']
#
# --------------------------------------------
#
# Hindi idiom: चार दिन की चांदनी फिर अँधेरी रात
# English idiom: A nine day’s wonder
#
# Tokenization:
# Hindi tokens: ['चार', 'दिन', 'की', 'चांदनी', 'फिर', 'अँधेरी', 'रात']
# English tokens: ['A', 'nine', 'day', '’', 's', 'wonder']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चार', 'दिन', 'की', 'चांदनी', 'फिर', 'अँधेरी', 'रात']
# English tokens without punctuation: ['A', 'nine', 'day', '’', 's', 'wonder']
#
# --------------------------------------------
#
# Hindi idiom: चोर-चोर मौसेरे भाई
# English idiom: Birds of a feather flock together
#
# Tokenization:
# Hindi tokens: ['चोर-चोर', 'मौसेरे', 'भाई']
# English tokens: ['Birds', 'of', 'a', 'feather', 'flock', 'together']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चोर-चोर', 'मौसेरे', 'भाई']
# English tokens without punctuation: ['Birds', 'of', 'a', 'feather', 'flock', 'together']
#
# --------------------------------------------
#
# Hindi idiom: चलती का नाम गाढ़ी
# English idiom: Nothing succeeds like success
#
# Tokenization:
# Hindi tokens: ['चलती', 'का', 'नाम', 'गाढ़ी']
# English tokens: ['Nothing', 'succeeds', 'like', 'success']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चलती', 'का', 'नाम', 'गाढ़ी']
# English tokens without punctuation: ['Nothing', 'succeeds', 'like', 'success']
#
# --------------------------------------------
#
# Hindi idiom: चोरी का गुड मीठा होता है
# English idiom: Forbidden fruit is sweet
#
# Tokenization:
# Hindi tokens: ['चोरी', 'का', 'गुड', 'मीठा', 'होता', 'है']
# English tokens: ['Forbidden', 'fruit', 'is', 'sweet']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['चोरी', 'का', 'गुड', 'मीठा', 'होता', 'है']
# English tokens without punctuation: ['Forbidden', 'fruit', 'is', 'sweet']
#
# --------------------------------------------
#
# Hindi idiom: जैसा करोगे वैसा भरोगे
# English idiom: As you sow, so shall you reap
#
# Tokenization:
# Hindi tokens: ['जैसा', 'करोगे', 'वैसा', 'भरोगे']
# English tokens: ['As', 'you', 'sow', ',', 'so', 'shall', 'you', 'reap']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जैसा', 'करोगे', 'वैसा', 'भरोगे']
# English tokens without punctuation: ['As', 'you', 'sow', 'so', 'shall', 'you', 'reap']
#
# --------------------------------------------
#
# Hindi idiom: जो गरजते हैं वो बरसते नहीं
# English idiom: Barking dog seldom bite
#
# Tokenization:
# Hindi tokens: ['जो', 'गरजते', 'हैं', 'वो', 'बरसते', 'नहीं']
# English tokens: ['Barking', 'dog', 'seldom', 'bite']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जो', 'गरजते', 'हैं', 'वो', 'बरसते', 'नहीं']
# English tokens without punctuation: ['Barking', 'dog', 'seldom', 'bite']
#
# --------------------------------------------
#
# Hindi idiom: जैसा आया वैसा गया
# English idiom: Evil gotten, evil spent
#
# Tokenization:
# Hindi tokens: ['जैसा', 'आया', 'वैसा', 'गया']
# English tokens: ['Evil', 'gotten', ',', 'evil', 'spent']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जैसा', 'आया', 'वैसा', 'गया']
# English tokens without punctuation: ['Evil', 'gotten', 'evil', 'spent']
#
# --------------------------------------------
#
# Hindi idiom: जाके पांव न फटी बुवाई सो क्या जाने पीर पराई
# English idiom: No one knows the weight of another’s burden
#
# Tokenization:
# Hindi tokens: ['जाके', 'पांव', 'न', 'फटी', 'बुवाई', 'सो', 'क्या', 'जाने', 'पीर', 'पराई']
# English tokens: ['No', 'one', 'knows', 'the', 'weight', 'of', 'another', '’', 's', 'burden']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जाके', 'पांव', 'न', 'फटी', 'बुवाई', 'सो', 'क्या', 'जाने', 'पीर', 'पराई']
# English tokens without punctuation: ['No', 'one', 'knows', 'the', 'weight', 'of', 'another', '’', 's', 'burden']
#
# --------------------------------------------
#
# Hindi idiom: जैसे को तैसा
# English idiom: Tit for tat
#
# Tokenization:
# Hindi tokens: ['जैसे', 'को', 'तैसा']
# English tokens: ['Tit', 'for', 'tat']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जैसे', 'को', 'तैसा']
# English tokens without punctuation: ['Tit', 'for', 'tat']
#
# --------------------------------------------
#
# Hindi idiom: जब तक सांस तब तक आस
# English idiom: Hope sustains life
#
# Tokenization:
# Hindi tokens: ['जब', 'तक', 'सांस', 'तब', 'तक', 'आस']
# English tokens: ['Hope', 'sustains', 'life']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जब', 'तक', 'सांस', 'तब', 'तक', 'आस']
# English tokens without punctuation: ['Hope', 'sustains', 'life']
#
# --------------------------------------------
#
# Hindi idiom: जितना गुड डालोगे उतना ही मीठा होगा
# English idiom: The deeper the well, the sweeter the water
#
# Tokenization:
# Hindi tokens: ['जितना', 'गुड', 'डालोगे', 'उतना', 'ही', 'मीठा', 'होगा']
# English tokens: ['The', 'deeper', 'the', 'well', ',', 'the', 'sweeter', 'the', 'water']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जितना', 'गुड', 'डालोगे', 'उतना', 'ही', 'मीठा', 'होगा']
# English tokens without punctuation: ['The', 'deeper', 'the', 'well', 'the', 'sweeter', 'the', 'water']
#
# --------------------------------------------
#
# Hindi idiom: जहाँ फूल वहां काँटा
# English idiom: Where there is a flower, there is a thorn
#
# Tokenization:
# Hindi tokens: ['जहाँ', 'फूल', 'वहां', 'काँटा']
# English tokens: ['Where', 'there', 'is', 'a', 'flower', ',', 'there', 'is', 'a', 'thorn']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जहाँ', 'फूल', 'वहां', 'काँटा']
# English tokens without punctuation: ['Where', 'there', 'is', 'a', 'flower', 'there', 'is', 'a', 'thorn']
#
# --------------------------------------------
#
# Hindi idiom: जितने मुहं उतनी ही बात
# English idiom: So many man, so many minds
#
# Tokenization:
# Hindi tokens: ['जितने', 'मुहं', 'उतनी', 'ही', 'बात']
# English tokens: ['So', 'many', 'man', ',', 'so', 'many', 'minds']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जितने', 'मुहं', 'उतनी', 'ही', 'बात']
# English tokens without punctuation: ['So', 'many', 'man', 'so', 'many', 'minds']
#
# --------------------------------------------
#
# Hindi idiom: झूठ के पांव नही होते
# English idiom: A liar has no legs to stand upon
#
# Tokenization:
# Hindi tokens: ['झूठ', 'के', 'पांव', 'नही', 'होते']
# English tokens: ['A', 'liar', 'has', 'no', 'legs', 'to', 'stand', 'upon']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['झूठ', 'के', 'पांव', 'नही', 'होते']
# English tokens without punctuation: ['A', 'liar', 'has', 'no', 'legs', 'to', 'stand', 'upon']
#
# --------------------------------------------
#
# Hindi idiom: डूबते को तिनके का सहारा
# English idiom: A drowning man catches at a straw
#
# Tokenization:
# Hindi tokens: ['डूबते', 'को', 'तिनके', 'का', 'सहारा']
# English tokens: ['A', 'drowning', 'man', 'catches', 'at', 'a', 'straw']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['डूबते', 'को', 'तिनके', 'का', 'सहारा']
# English tokens without punctuation: ['A', 'drowning', 'man', 'catches', 'at', 'a', 'straw']
#
# --------------------------------------------
#
# Hindi idiom: डरे सो मरे
# English idiom: Cowards die so many times before their death
#
# Tokenization:
# Hindi tokens: ['डरे', 'सो', 'मरे']
# English tokens: ['Cowards', 'die', 'so', 'many', 'times', 'before', 'their', 'death']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['डरे', 'सो', 'मरे']
# English tokens without punctuation: ['Cowards', 'die', 'so', 'many', 'times', 'before', 'their', 'death']
#
# --------------------------------------------
#
# Hindi idiom: तेते पावं पसारिये जेती लम्बी सौर
# English idiom: Cut your coat according to your cloth
#
# Tokenization:
# Hindi tokens: ['तेते', 'पावं', 'पसारिये', 'जेती', 'लम्बी', 'सौर']
# English tokens: ['Cut', 'your', 'coat', 'according', 'to', 'your', 'cloth']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['तेते', 'पावं', 'पसारिये', 'जेती', 'लम्बी', 'सौर']
# English tokens without punctuation: ['Cut', 'your', 'coat', 'according', 'to', 'your', 'cloth']
#
# --------------------------------------------
#
# Hindi idiom: तुम तो ईद के चाँद हो गये
# English idiom: Your visits are few and far between
#
# Tokenization:
# Hindi tokens: ['तुम', 'तो', 'ईद', 'के', 'चाँद', 'हो', 'गये']
# English tokens: ['Your', 'visits', 'are', 'few', 'and', 'far', 'between']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['तुम', 'तो', 'ईद', 'के', 'चाँद', 'हो', 'गये']
# English tokens without punctuation: ['Your', 'visits', 'are', 'few', 'and', 'far', 'between']
#
# --------------------------------------------
#
# Hindi idiom: तुम एक ही थैली के चट्टे-बट्टे हो
# English idiom: You are chips of the same block
#
# Tokenization:
# Hindi tokens: ['तुम', 'एक', 'ही', 'थैली', 'के', 'चट्टे-बट्टे', 'हो']
# English tokens: ['You', 'are', 'chips', 'of', 'the', 'same', 'block']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['तुम', 'एक', 'ही', 'थैली', 'के', 'चट्टे-बट्टे', 'हो']
# English tokens without punctuation: ['You', 'are', 'chips', 'of', 'the', 'same', 'block']
#
# --------------------------------------------
#
# Hindi idiom: तंदरुस्ती हजार नियामत
# English idiom: Good health is above wealth
#
# Tokenization:
# Hindi tokens: ['तंदरुस्ती', 'हजार', 'नियामत']
# English tokens: ['Good', 'health', 'is', 'above', 'wealth']
#
# Lowercasing:
#
# Punctuation Removal:
# ...
# Hindi tokens without punctuation: ['मुश्किल', 'से', 'मुश्किल', 'का', 'सामना', 'करना']
# English tokens without punctuation: ['Crossing', 'the', 'Rubicon']
#
# --------------------------------------------
#
# Hindi idiom: अंधा-धूप में बैठना
# English idiom: Turn a blind eye
#
# Tokenization:
# Hindi tokens: ['अंधा-धूप', 'में', 'बैठना']
# English tokens: ['Turn', 'a', 'blind', 'eye']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अंधा-धूप', 'में', 'बैठना']
# English tokens without punctuation: ['Turn', 'a', 'blind', 'eye']
#
# --------------------------------------------
#
# Hindi idiom: तोता उड़ गया
# English idiom: Kick the bucket
#
# Tokenization:
# Hindi tokens: ['तोता', 'उड़', 'गया']
# English tokens: ['Kick', 'the', 'bucket']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['तोता', 'उड़', 'गया']
# English tokens without punctuation: ['Kick', 'the', 'bucket']
#
# --------------------------------------------
#
# Hindi idiom: बिल्कुल साफ़-सुथरा
# English idiom: Crystal clear
#
# Tokenization:
# Hindi tokens: ['बिल्कुल', 'साफ़-सुथरा']
# English tokens: ['Crystal', 'clear']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बिल्कुल', 'साफ़-सुथरा']
# English tokens without punctuation: ['Crystal', 'clear']
#
# --------------------------------------------
#
# Hindi idiom: अंधा कानूना रेवड़ी राजा
# English idiom: Blind cat, king of the sugarcane field
#
# Tokenization:
# Hindi tokens: ['अंधा', 'कानूना', 'रेवड़ी', 'राजा']
# English tokens: ['Blind', 'cat', ',', 'king', 'of', 'the', 'sugarcane', 'field']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अंधा', 'कानूना', 'रेवड़ी', 'राजा']
# English tokens without punctuation: ['Blind', 'cat', 'king', 'of', 'the', 'sugarcane', 'field']
#
# --------------------------------------------
#
# Hindi idiom: अच्छे दिन आने वाले हैं
# English idiom: The best is yet to come
#
# Tokenization:
# Hindi tokens: ['अच्छे', 'दिन', 'आने', 'वाले', 'हैं']
# English tokens: ['The', 'best', 'is', 'yet', 'to', 'come']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अच्छे', 'दिन', 'आने', 'वाले', 'हैं']
# English tokens without punctuation: ['The', 'best', 'is', 'yet', 'to', 'come']
#
# --------------------------------------------
#
# Hindi idiom: जल में रहकर मगर से बेराबर
# English idiom: Like a fish out of water
#
# Tokenization:
# Hindi tokens: ['जल', 'में', 'रहकर', 'मगर', 'से', 'बेराबर']
# English tokens: ['Like', 'a', 'fish', 'out', 'of', 'water']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['जल', 'में', 'रहकर', 'मगर', 'से', 'बेराबर']
# English tokens without punctuation: ['Like', 'a', 'fish', 'out', 'of', 'water']
#
# --------------------------------------------
#
# Hindi idiom: छोटा हाथी, बड़ा काम
# English idiom: Little strokes fell great oaks
#
# Tokenization:
# Hindi tokens: ['छोटा', 'हाथी', ',', 'बड़ा', 'काम']
# English tokens: ['Little', 'strokes', 'fell', 'great', 'oaks']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['छोटा', 'हाथी', 'बड़ा', 'काम']
# English tokens without punctuation: ['Little', 'strokes', 'fell', 'great', 'oaks']
#
# --------------------------------------------
#
# Hindi idiom: अपने पैर पे कुल्हाड़ी मारना
# English idiom: To dig one's own grave
#
# Tokenization:
# Hindi tokens: ['अपने', 'पैर', 'पे', 'कुल्हाड़ी', 'मारना']
# English tokens: ['To', 'dig', 'one', "'s", 'own', 'grave']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अपने', 'पैर', 'पे', 'कुल्हाड़ी', 'मारना']
# English tokens without punctuation: ['To', 'dig', 'one', "'s", 'own', 'grave']
#
# --------------------------------------------
#
# Hindi idiom: बीज से बीज मिलते हैं
# English idiom: As you sow, so shall you reap
#
# Tokenization:
# Hindi tokens: ['बीज', 'से', 'बीज', 'मिलते', 'हैं']
# English tokens: ['As', 'you', 'sow', ',', 'so', 'shall', 'you', 'reap']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बीज', 'से', 'बीज', 'मिलते', 'हैं']
# English tokens without punctuation: ['As', 'you', 'sow', 'so', 'shall', 'you', 'reap']
#
# --------------------------------------------
#
# Hindi idiom: राजा का स्वाभाव ही राजा का भय
# English idiom: Still waters run deep
#
# Tokenization:
# Hindi tokens: ['राजा', 'का', 'स्वाभाव', 'ही', 'राजा', 'का', 'भय']
# English tokens: ['Still', 'waters', 'run', 'deep']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['राजा', 'का', 'स्वाभाव', 'ही', 'राजा', 'का', 'भय']
# English tokens without punctuation: ['Still', 'waters', 'run', 'deep']
#
# --------------------------------------------
#
# Hindi idiom: लालच बुरी बला है
# English idiom: Greed is a curse
#
# Tokenization:
# Hindi tokens: ['लालच', 'बुरी', 'बला', 'है']
# English tokens: ['Greed', 'is', 'a', 'curse']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['लालच', 'बुरी', 'बला', 'है']
# English tokens without punctuation: ['Greed', 'is', 'a', 'curse']
#
# --------------------------------------------
#
# Hindi idiom: सोने पे सुहागा
# English idiom: Icing on the cake
#
# Tokenization:
# Hindi tokens: ['सोने', 'पे', 'सुहागा']
# English tokens: ['Icing', 'on', 'the', 'cake']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['सोने', 'पे', 'सुहागा']
# English tokens without punctuation: ['Icing', 'on', 'the', 'cake']
#
# --------------------------------------------
#
# Hindi idiom: हर मुश्किल के पीछे एक राह होती है
# English idiom: Every cloud has a silver lining
#
# Tokenization:
# Hindi tokens: ['हर', 'मुश्किल', 'के', 'पीछे', 'एक', 'राह', 'होती', 'है']
# English tokens: ['Every', 'cloud', 'has', 'a', 'silver', 'lining']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['हर', 'मुश्किल', 'के', 'पीछे', 'एक', 'राह', 'होती', 'है']
# English tokens without punctuation: ['Every', 'cloud', 'has', 'a', 'silver', 'lining']
#
# --------------------------------------------
#
# Hindi idiom: बुरा जो देखन मैं चला, बुरा न मिलिया कोई
# English idiom: No one's evil deeds go unnoticed
#
# Tokenization:
# Hindi tokens: ['बुरा', 'जो', 'देखन', 'मैं', 'चला', ',', 'बुरा', 'न', 'मिलिया', 'कोई']
# English tokens: ['No', 'one', "'s", 'evil', 'deeds', 'go', 'unnoticed']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बुरा', 'जो', 'देखन', 'मैं', 'चला', 'बुरा', 'न', 'मिलिया', 'कोई']
# English tokens without punctuation: ['No', 'one', "'s", 'evil', 'deeds', 'go', 'unnoticed']
#
# --------------------------------------------
#
# Hindi idiom: आलसी की भैंस बहुत जल्दी खाती है
# English idiom: Lazy people work the hardest
#
# Tokenization:
# Hindi tokens: ['आलसी', 'की', 'भैंस', 'बहुत', 'जल्दी', 'खाती', 'है']
# English tokens: ['Lazy', 'people', 'work', 'the', 'hardest']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आलसी', 'की', 'भैंस', 'बहुत', 'जल्दी', 'खाती', 'है']
# English tokens without punctuation: ['Lazy', 'people', 'work', 'the', 'hardest']
#
# --------------------------------------------
#
# Hindi idiom: अपने पैर पर खड़ा होना
# English idiom: To stand on one's own feet
#
# Tokenization:
# Hindi tokens: ['अपने', 'पैर', 'पर', 'खड़ा', 'होना']
# English tokens: ['To', 'stand', 'on', 'one', "'s", 'own', 'feet']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अपने', 'पैर', 'पर', 'खड़ा', 'होना']
# English tokens without punctuation: ['To', 'stand', 'on', 'one', "'s", 'own', 'feet']
#
# --------------------------------------------
#
# Hindi idiom: भूखे को रोटी देखने को रुटी
# English idiom: When you are hungry, even a simple meal looks appealing
#
# Tokenization:
# Hindi tokens: ['भूखे', 'को', 'रोटी', 'देखने', 'को', 'रुटी']
# English tokens: ['When', 'you', 'are', 'hungry', ',', 'even', 'a', 'simple', 'meal', 'looks', 'appealing']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['भूखे', 'को', 'रोटी', 'देखने', 'को', 'रुटी']
# English tokens without punctuation: ['When', 'you', 'are', 'hungry', 'even', 'a', 'simple', 'meal', 'looks', 'appealing']
#
# --------------------------------------------
#
# Hindi idiom: बंदर के हाथ में तलवार
# English idiom: Giving a loaded gun to a monkey
#
# Tokenization:
# Hindi tokens: ['बंदर', 'के', 'हाथ', 'में', 'तलवार']
# English tokens: ['Giving', 'a', 'loaded', 'gun', 'to', 'a', 'monkey']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बंदर', 'के', 'हाथ', 'में', 'तलवार']
# English tokens without punctuation: ['Giving', 'a', 'loaded', 'gun', 'to', 'a', 'monkey']
#
# --------------------------------------------
#
# Hindi idiom: बूँद-बूँद से सागर भरता है
# English idiom: Every little helps
#
# Tokenization:
# Hindi tokens: ['बूँद-बूँद', 'से', 'सागर', 'भरता', 'है']
# English tokens: ['Every', 'little', 'helps']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बूँद-बूँद', 'से', 'सागर', 'भरता', 'है']
# English tokens without punctuation: ['Every', 'little', 'helps']
#
# --------------------------------------------
#
# Hindi idiom: बैल का बच्चा चार पैर का होता है
# English idiom: A chip off the old block
#
# Tokenization:
# Hindi tokens: ['बैल', 'का', 'बच्चा', 'चार', 'पैर', 'का', 'होता', 'है']
# English tokens: ['A', 'chip', 'off', 'the', 'old', 'block']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बैल', 'का', 'बच्चा', 'चार', 'पैर', 'का', 'होता', 'है']
# English tokens without punctuation: ['A', 'chip', 'off', 'the', 'old', 'block']
#
# --------------------------------------------
#
# Hindi idiom: बुरी नजर वाले तेरा मुंह काला
# English idiom: The evil eye is on you
#
# Tokenization:
# Hindi tokens: ['बुरी', 'नजर', 'वाले', 'तेरा', 'मुंह', 'काला']
# English tokens: ['The', 'evil', 'eye', 'is', 'on', 'you']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बुरी', 'नजर', 'वाले', 'तेरा', 'मुंह', 'काला']
# English tokens without punctuation: ['The', 'evil', 'eye', 'is', 'on', 'you']
#
# --------------------------------------------
#
# Hindi idiom: बैठे बैठे क्या करेगा गोधूलि दादा
# English idiom: Idle hands are the devil's workshop
#
# Tokenization:
# Hindi tokens: ['बैठे', 'बैठे', 'क्या', 'करेगा', 'गोधूलि', 'दादा']
# English tokens: ['Idle', 'hands', 'are', 'the', "devil's", 'workshop']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['बैठे', 'बैठे', 'क्या', 'करेगा', 'गोधूलि', 'दादा']
# English tokens without punctuation: ['Idle', 'hands', 'are', 'the', "devil's", 'workshop']
#
# --------------------------------------------
#
# Hindi idiom: अपनी खोज में जुटा रहना
# English idiom: To be lost in one's own thoughts
#
# Tokenization:
# Hindi tokens: ['अपनी', 'खोज', 'में', 'जुटा', 'रहना']
# English tokens: ['To', 'be', 'lost', 'in', 'one', "'s", 'own', 'thoughts']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अपनी', 'खोज', 'में', 'जुटा', 'रहना']
# English tokens without punctuation: ['To', 'be', 'lost', 'in', 'one', "'s", 'own', 'thoughts']
#
# --------------------------------------------
#
# Hindi idiom: अबे तकिया लेना
# English idiom: To take things lightly
#
# Tokenization:
# Hindi tokens: ['अबे', 'तकिया', 'लेना']
# English tokens: ['To', 'take', 'things', 'lightly']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अबे', 'तकिया', 'लेना']
# English tokens without punctuation: ['To', 'take', 'things', 'lightly']
#
# --------------------------------------------
#
# Hindi idiom: आलसी का बींग बनना
# English idiom: To become a couch potato
#
# Tokenization:
# Hindi tokens: ['आलसी', 'का', 'बींग', 'बनना']
# English tokens: ['To', 'become', 'a', 'couch', 'potato']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आलसी', 'का', 'बींग', 'बनना']
# English tokens without punctuation: ['To', 'become', 'a', 'couch', 'potato']
#
# --------------------------------------------
#
# Hindi idiom: अब और नहीं
# English idiom: No more, thank you
#
# Tokenization:
# Hindi tokens: ['अब', 'और', 'नहीं']
# English tokens: ['No', 'more', ',', 'thank', 'you']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अब', 'और', 'नहीं']
# English tokens without punctuation: ['No', 'more', 'thank', 'you']
#
# --------------------------------------------
#
# Hindi idiom: अपना साँप खुद ही मारा
# English idiom: Shooting oneself in the foot
#
# Tokenization:
# Hindi tokens: ['अपना', 'साँप', 'खुद', 'ही', 'मारा']
# English tokens: ['Shooting', 'oneself', 'in', 'the', 'foot']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अपना', 'साँप', 'खुद', 'ही', 'मारा']
# English tokens without punctuation: ['Shooting', 'oneself', 'in', 'the', 'foot']
#
# --------------------------------------------
#
# Hindi idiom: आबू के आज़मा गाड़ी में बैठना
# English idiom: To have one's head in the clouds
#
# Tokenization:
# Hindi tokens: ['आबू', 'के', 'आज़मा', 'गाड़ी', 'में', 'बैठना']
# English tokens: ['To', 'have', 'one', "'s", 'head', 'in', 'the', 'clouds']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आबू', 'के', 'आज़मा', 'गाड़ी', 'में', 'बैठना']
# English tokens without punctuation: ['To', 'have', 'one', "'s", 'head', 'in', 'the', 'clouds']
#
# --------------------------------------------
#
# Hindi idiom: आंख का आंखा नुंबा
# English idiom: An eye for an eye
#
# Tokenization:
# Hindi tokens: ['आंख', 'का', 'आंखा', 'नुंबा']
# English tokens: ['An', 'eye', 'for', 'an', 'eye']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आंख', 'का', 'आंखा', 'नुंबा']
# English tokens without punctuation: ['An', 'eye', 'for', 'an', 'eye']
#
# --------------------------------------------
#
# Hindi idiom: अब्दुल्ला देवना भला तो हो भला
# English idiom: A good deed never goes unrewarded
#
# Tokenization:
# Hindi tokens: ['अब्दुल्ला', 'देवना', 'भला', 'तो', 'हो', 'भला']
# English tokens: ['A', 'good', 'deed', 'never', 'goes', 'unrewarded']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अब्दुल्ला', 'देवना', 'भला', 'तो', 'हो', 'भला']
# English tokens without punctuation: ['A', 'good', 'deed', 'never', 'goes', 'unrewarded']
#
# --------------------------------------------
#
# Hindi idiom: आजमा रहे हो तो सफल होगा
# English idiom: Nothing ventured, nothing gained
#
# Tokenization:
# Hindi tokens: ['आजमा', 'रहे', 'हो', 'तो', 'सफल', 'होगा']
# English tokens: ['Nothing', 'ventured', ',', 'nothing', 'gained']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आजमा', 'रहे', 'हो', 'तो', 'सफल', 'होगा']
# English tokens without punctuation: ['Nothing', 'ventured', 'nothing', 'gained']
#
# --------------------------------------------
#
# Hindi idiom: आँधी में रहकर बैर नहीं करना
# English idiom: Do not bear ill will while living in a storm
#
# Tokenization:
# Hindi tokens: ['आँधी', 'में', 'रहकर', 'बैर', 'नहीं', 'करना']
# English tokens: ['Do', 'not', 'bear', 'ill', 'will', 'while', 'living', 'in', 'a', 'storm']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['आँधी', 'में', 'रहकर', 'बैर', 'नहीं', 'करना']
# English tokens without punctuation: ['Do', 'not', 'bear', 'ill', 'will', 'while', 'living', 'in', 'a', 'storm']
#
# --------------------------------------------
#
# Hindi idiom: अबला नहीं, सबला
# English idiom: Not helpless, but powerful
#
# Tokenization:
# Hindi tokens: ['अबला', 'नहीं', ',', 'सबला']
# English tokens: ['Not', 'helpless', ',', 'but', 'powerful']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अबला', 'नहीं', 'सबला']
# English tokens without punctuation: ['Not', 'helpless', 'but', 'powerful']
#
# --------------------------------------------
#
# Hindi idiom: अल्लाह मेहरबान तो गधा पहेलवान
# English idiom: God helps those who help themselves
#
# Tokenization:
# Hindi tokens: ['अल्लाह', 'मेहरबान', 'तो', 'गधा', 'पहेलवान']
# English tokens: ['God', 'helps', 'those', 'who', 'help', 'themselves']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['अल्लाह', 'मेहरबान', 'तो', 'गधा', 'पहेलवान']
# English tokens without punctuation: ['God', 'helps', 'those', 'who', 'help', 'themselves']
#
# --------------------------------------------
#
# Hindi idiom: हड्डियों की चिंगारी मत लगाओ
# English idiom: Do not provoke a hornet's nest
#
# Tokenization:
# Hindi tokens: ['हड्डियों', 'की', 'चिंगारी', 'मत', 'लगाओ']
# English tokens: ['Do', 'not', 'provoke', 'a', 'hornet', "'s", 'nest']
#
# Lowercasing:
#
# Punctuation Removal:
# Hindi tokens without punctuation: ['हड्डियों', 'की', 'चिंगारी', 'मत', 'लगाओ']
# English tokens without punctuation: ['Do', 'not', 'provoke', 'a', 'hornet', "'s", 'nest']
#
# --------------------------------------------

# %% [markdown]
# **Using Sequence Matcher**

# %%
import re
import pandas as pd
from nltk.tokenize import word_tokenize
from difflib import SequenceMatcher

# Read the CSV file containing Hindi idioms
df = pd.read_csv('/content/drive/MyDrive/Copy of Copy of shareddocgog.csv')

# Define a function to preprocess sentences
def preprocess_sentence(sentence):
    # Tokenization
    tokens = word_tokenize(sentence)

    # Remove punctuation
    tokens = [word for word in tokens if word.isalnum()]

    return tokens

# Define a function to compute similarity between two strings
def similarity(a, b):
    return SequenceMatcher(None, a, b).ratio()

# Define a function to detect Hindi idioms in a sentence
def detect_hindi_idioms(sentence, hindi_idioms):
    most_matching_idiom = None
    max_similarity = 0

    # Tokenize the input sentence
    tokenized_sentence = set(preprocess_sentence(sentence))

    # Iterate through Hindi idioms
    for idiom in hindi_idioms:
        # Tokenize the Hindi idiom
        tokenized_idiom = set(preprocess_sentence(idiom))

        # Calculate similarity between tokens of the idiom and tokens of the sentence
        sim = similarity(tokenized_sentence, tokenized_idiom)

        # Update most matching idiom if similarity is higher
        if sim > max_similarity:
            most_matching_idiom = idiom
            max_similarity = sim

    return most_matching_idiom  # Return the most matching idiom

# Example input sentence
example_input_sentence = "उसने अपने साथी के प्रति संदेह जताने के लिए कभी भी चोर की दाढ़ी में तिनका बना दिया।"
#example_input_sentence = "वह लोगों को मुह में राम बगल में छुरी बताता है, पर असल में उसके कारनामे कभी नहीं सुधरते।"
#example_input_sentence = "वह अपनी गलतियों को छुपाने के लिए उल्टा चोर कोतवाल को डांट रहा है।"
#example_input_sentence = "उसका व्यवहार देखकर लगता है, जैसा देश वैसा भेष है।"
#example_input_sentence = "वह सबका मार्गदर्शन करता है, अंधों में काना राजा बन गया है।"
#example_input_sentence = "उसके पास पैसे होने के कारण, वह हमेशा जिसकी लाठी उसकी भैंस बनता है।"
#example_input_sentence = "उसे उसकी जिम्मेदारी का महत्व नहीं समझाई जा सकती, उसके लिए घर की मुर्गी दाल बराबर है।"


# Initialize variables to store the most matching idiom and its similarity score
best_idiom = None
best_similarity = 0

# Iterate over each row in the dataset
for index, row in df.iterrows():
    hindi_idiom = row['hindi_idiom']  # Extract the Hindi idiom from the CSV row

    # Calculate similarity between the input sentence and the current Hindi idiom
    sim = similarity(example_input_sentence, hindi_idiom)

    # Update the best matching idiom if the similarity is higher
    if sim > best_similarity:
        best_idiom = hindi_idiom
        best_similarity = sim

# Print the best matching idiom
print("Input Sentence:", example_input_sentence)
if best_idiom:
    print("Detected Hindi Idiom:", best_idiom)
else:
    print("Hindi idiom not detected in the sentence.")
# Out:
# Input Sentence: उसने अपने साथी के प्रति संदेह जताने के लिए कभी भी चोर की दाढ़ी में तिनका बना दिया।
# Detected Hindi Idiom: चोर की दाढ़ी में तिनका
